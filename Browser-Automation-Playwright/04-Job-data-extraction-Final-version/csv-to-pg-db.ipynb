# %%
import pandas as pd

# %%
ds_data = pd.read_csv("output/data_science_jobs.csv")
ds_data.sample(2)
# Out:
#                                                 title  \
# 13                                  Computer Operator
# 2   Team Leader / Assistant Manager - Quality Cont...
#
#                                          details_link       company_name  \
# 13  https://jobs.bdjobs.com/jobdetails/?id=1384595...        Shiny Steps
# 2   https://jobs.bdjobs.com/jobdetails/?id=1386726...  A Reputed Company
#
#    company_logo                location     deadline experience
# 13          NaN                  Sylhet  25 Jul 2025         Na
# 2           NaN  Anywhere in Bangladesh  16 Aug 2025         Na

# %%
ds_data
# Out:
#                                                 title  \
# 0   Junior Instructor/Instructor, Computer Science...
# 1                                Electrical Estimator
# 2   Team Leader / Assistant Manager - Quality Cont...
# 3                                 Electrical Engineer
# 4                                     Project Officer
# 5                       Executive (Sales & Marketing)
# 6                                   Junior Instructor
# 7                        Marketing Executive (Fabric)
# 8                                     Product Manager
# 9                               কম্পিউটার টেকনিশিয়ান
# 10  Computer Operator (Graphics Design and Video E...
# 11                                  Computer Operator
# 12                                  Computer Operator
# 13                                  Computer Operator
# 14                     Data Entry / Computer Operator
# 15              Data Entry Operator (Day/Night Shift)
# ...
